# %%
import os
import pandas as pd
import numpy as np
from dotenv import load_dotenv
from pathlib import Path
from datetime import datetime
import requests

# %%
df = pd.read_csv(Path('./data/us_equities_news_dataset.csv'))
df.head()
# Out:
#        id ticker                                              title category  \
# 0  221515    NIO  Why Shares of Chinese Electric Car Maker NIO A...     news
# 1  221516    NIO  NIO only consumer gainer  Workhorse Group amon...     news
# 2  221517    NIO  NIO leads consumer gainers  Beyond Meat and Ma...     news
# 3  221518    NIO                  NIO  NVAX among premarket gainers     news
# 4  221519    NIO                  PLUG  NIO among premarket gainers     news
#
#                                              content release_date  \
# 0  What s happening\nShares of Chinese electric c...   2020-01-15
# 1  Gainers  NIO  NYSE NIO   7  \nLosers  MGP Ingr...   2020-01-18
# 2  Gainers  NIO  NYSE NIO   14   Village Farms In...   2020-01-15
# 3  Cemtrex  NASDAQ CETX   85  after FY results \n...   2020-01-15
# 4  aTyr Pharma  NASDAQ LIFE   63  on Kyorin Pharm...   2020-01-06
#
#           provider                                                url  \
# 0  The Motley Fool                             https://invst.ly/pigqi
# 1    Seeking Alpha                             https://invst.ly/pje9c
# 2    Seeking Alpha                             https://invst.ly/pifmv
# 3    Seeking Alpha                             https://invst.ly/picu8
# 4    Seeking Alpha  https://seekingalpha.com/news/3529772-plug-nio...
#
#    article_id
# 0     2060327
# 1     2062196
# 2     2060249
# 3     2060039
# 4     2053096

# %%
df.tail()
# Out:
#             id ticker                                              title  \
# 221508  443024      T                     Crude And Steel Still In Sync
# 221509  443025      T  Forget AT T  This Is The Telecom Stock You Sho...
# 221510  443026      T  Wall Street Exposed   Part 3   How Dividends C...
# 221511  443027      T       Weighing The Week Ahead  It s All About Jobs
# 221512  443028      T  Leap Wireless  LEAP    JPM Note and AT T   T M...
#
#        category                                            content  \
# 221508  opinion  We have been reporting on the trade off betwee...
# 221509  opinion  It s the largest cell phone provider in the wo...
# 221510  opinion  Before we dicuss how the mechanism of dividend...
# 221511  opinion  From start to finish  the coming week will hav...
# 221512  opinion  Leap Wireless International  Inc   Leap  is a ...
#
#        release_date         provider  \
# 221508   2012-10-04       Ivan Kitov
# 221509   2012-05-30  StreetAuthority
# 221510   2012-07-16   Portfolio Cafe
# 221511   2012-09-02      Jeff Miller
# 221512   2011-12-31   Ophir Gottlieb
#
#                                                       url  article_id
# 221508  https://www.investing.com/analysis/crude-and-s...      138733
# 221509  https://www.investing.com/analysis/forget-at-t...      124829
# 221510  https://www.investing.com/analysis/wall-street...      129651
# 221511  https://www.investing.com/analysis/weighing-th...      134926
# 221512  https://www.investing.com/analysis/leap-wirele...      110079

# %%
df.loc[df['ticker'] == 'VAS']
# Out:
# Empty DataFrame
# Columns: [id, ticker, title, category, content, release_date, provider, url, article_id]
# Index: []

# %%
URL = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
tickers = pd.read_html(URL)[0]['Symbol'].tolist()
tickers
# Out:
# ['MMM',
#  'AOS',
#  'ABT',
#  'ABBV',
#  'ACN',
#  'ATVI',
#  'ADM',
#  'ADBE',
#  'ADP',
#  'AAP',
#  'AES',
#  'AFL',
#  'A',
#  'APD',
#  'AKAM',
#  'ALK',
#  'ALB',
#  'ARE',
#  'ALGN',
#  'ALLE',
#  'LNT',
#  'ALL',
#  'GOOGL',
#  'GOOG',
#  'MO',
#  'AMZN',
#  'AMCR',
#  'AMD',
#  'AEE',
#  'AAL',
#  'AEP',
#  'AXP',
#  'AIG',
#  'AMT',
#  'AWK',
#  'AMP',
#  'ABC',
#  'AME',
#  'AMGN',
#  'APH',
#  'ADI',
#  'ANSS',
#  'AON',
#  'APA',
#  'AAPL',
#  'AMAT',
#  'APTV',
#  'ACGL',
#  'ANET',
#  'AJG',
#  'AIZ',
#  'T',
#  'ATO',
#  'ADSK',
#  'AZO',
#  'AVB',
#  'AVY',
#  'BKR',
#  'BALL',
#  'BAC',
#  'BBWI',
#  'BAX',
#  'BDX',
#  'WRB',
#  'BRK.B',
#  'BBY',
#  'BIO',
#  'TECH',
#  'BIIB',
#  'BLK',
#  'BK',
#  'BA',
#  'BKNG',
#  'BWA',
#  'BXP',
#  'BSX',
#  'BMY',
#  'AVGO',
#  'BR',
#  'BRO',
#  'BF.B',
#  'CHRW',
#  'CDNS',
#  'CZR',
#  'CPT',
#  'CPB',
#  'COF',
#  'CAH',
#  'KMX',
#  'CCL',
#  'CARR',
#  'CTLT',
#  'CAT',
#  'CBOE',
#  'CBRE',
#  'CDW',
#  'CE',
#  'CNC',
#  'CNP',
#  'CDAY',
#  'CF',
#  'CRL',
#  'SCHW',
#  'CHTR',
#  'CVX',
#  'CMG',
#  'CB',
#  'CHD',
#  'CI',
#  'CINF',
#  'CTAS',
#  'CSCO',
#  'C',
#  'CFG',
#  'CLX',
#  'CME',
#  'CMS',
#  'KO',
#  'CTSH',
#  'CL',
#  'CMCSA',
#  'CMA',
#  'CAG',
#  'COP',
#  'ED',
#  'STZ',
#  'CEG',
#  'COO',
#  'CPRT',
#  'GLW',
#  'CTVA',
#  'CSGP',
#  'COST',
#  'CTRA',
#  'CCI',
#  'CSX',
#  'CMI',
#  'CVS',
#  'DHI',
#  'DHR',
#  'DRI',
#  'DVA',
#  'DE',
#  'DAL',
#  'XRAY',
#  'DVN',
#  'DXCM',
#  'FANG',
#  'DLR',
#  'DFS',
#  'DISH',
#  'DIS',
#  'DG',
#  'DLTR',
#  'D',
#  'DPZ',
#  'DOV',
#  'DOW',
#  'DTE',
#  'DUK',
#  'DD',
#  'DXC',
#  'EMN',
#  'ETN',
#  'EBAY',
#  'ECL',
#  'EIX',
#  'EW',
#  'EA',
#  'ELV',
#  'LLY',
#  'EMR',
#  'ENPH',
#  'ETR',
#  'EOG',
#  'EPAM',
#  'EQT',
#  'EFX',
#  'EQIX',
#  'EQR',
#  'ESS',
#  'EL',
#  'ETSY',
#  'RE',
#  'EVRG',
#  'ES',
#  'EXC',
#  'EXPE',
#  'EXPD',
#  'EXR',
#  'XOM',
#  'FFIV',
#  'FDS',
#  'FAST',
#  'FRT',
#  'FDX',
#  'FITB',
#  'FRC',
#  'FSLR',
#  'FE',
#  'FIS',
#  'FISV',
#  'FLT',
#  'FMC',
#  'F',
#  'FTNT',
#  'FTV',
#  'FOXA',
#  'FOX',
#  'BEN',
#  'FCX',
#  'GRMN',
#  'IT',
#  'GEN',
#  'GNRC',
#  'GD',
#  'GE',
#  'GIS',
#  'GM',
#  'GPC',
#  'GILD',
#  'GL',
#  'GPN',
#  'GS',
#  'HAL',
#  'HIG',
#  'HAS',
#  'HCA',
#  'PEAK',
#  'HSIC',
#  'HSY',
#  'HES',
#  'HPE',
#  'HLT',
#  'HOLX',
#  'HD',
#  'HON',
#  'HRL',
#  'HST',
#  'HWM',
#  'HPQ',
#  'HUM',
#  'HBAN',
#  'HII',
#  'IBM',
#  'IEX',
#  'IDXX',
#  'ITW',
#  'ILMN',
#  'INCY',
#  'IR',
#  'INTC',
#  'ICE',
#  'IP',
#  'IPG',
#  'IFF',
#  'INTU',
#  'ISRG',
#  'IVZ',
#  'INVH',
#  'IQV',
#  'IRM',
#  'JBHT',
#  'JKHY',
#  'J',
#  'JNJ',
#  'JCI',
#  'JPM',
#  'JNPR',
#  'K',
#  'KDP',
#  'KEY',
#  'KEYS',
#  'KMB',
#  'KIM',
#  'KMI',
#  'KLAC',
#  'KHC',
#  'KR',
#  'LHX',
#  'LH',
#  'LRCX',
#  'LW',
#  'LVS',
#  'LDOS',
#  'LEN',
#  'LNC',
#  'LIN',
#  'LYV',
#  'LKQ',
#  'LMT',
#  'L',
#  'LOW',
#  'LUMN',
#  'LYB',
#  'MTB',
#  'MRO',
#  'MPC',
#  'MKTX',
#  'MAR',
#  'MMC',
#  'MLM',
#  'MAS',
#  'MA',
#  'MTCH',
#  'MKC',
#  'MCD',
#  'MCK',
#  'MDT',
#  'MRK',
#  'META',
#  'MET',
#  'MTD',
#  'MGM',
#  'MCHP',
#  'MU',
#  'MSFT',
#  'MAA',
#  'MRNA',
#  'MHK',
#  'MOH',
#  'TAP',
#  'MDLZ',
#  'MPWR',
#  'MNST',
#  'MCO',
#  'MS',
#  'MOS',
#  'MSI',
#  'MSCI',
#  'NDAQ',
#  'NTAP',
#  'NFLX',
#  'NWL',
#  'NEM',
#  'NWSA',
#  'NWS',
#  'NEE',
#  'NKE',
#  'NI',
#  'NDSN',
#  'NSC',
#  'NTRS',
#  'NOC',
#  'NCLH',
#  'NRG',
#  'NUE',
#  'NVDA',
#  'NVR',
#  'NXPI',
#  'ORLY',
#  'OXY',
#  'ODFL',
#  'OMC',
#  'ON',
#  'OKE',
#  'ORCL',
#  'OGN',
#  'OTIS',
#  'PCAR',
#  'PKG',
#  'PARA',
#  'PH',
#  'PAYX',
#  'PAYC',
#  'PYPL',
#  'PNR',
#  'PEP',
#  'PKI',
#  'PFE',
#  'PCG',
#  'PM',
#  'PSX',
#  'PNW',
#  'PXD',
#  'PNC',
#  'POOL',
#  'PPG',
#  'PPL',
#  'PFG',
#  'PG',
#  'PGR',
#  'PLD',
#  'PRU',
#  'PEG',
#  'PTC',
#  'PSA',
#  'PHM',
#  'QRVO',
#  'PWR',
#  'QCOM',
#  'DGX',
#  'RL',
#  'RJF',
#  'RTX',
#  'O',
#  'REG',
#  'REGN',
#  'RF',
#  'RSG',
#  'RMD',
#  'RHI',
#  'ROK',
#  'ROL',
#  'ROP',
#  'ROST',
#  'RCL',
#  'SPGI',
#  'CRM',
#  'SBAC',
#  'SLB',
#  'STX',
#  'SEE',
#  'SRE',
#  'NOW',
#  'SHW',
#  'SBNY',
#  'SPG',
#  'SWKS',
#  'SJM',
#  'SNA',
#  'SEDG',
#  'SO',
#  'LUV',
#  'SWK',
#  'SBUX',
#  'STT',
#  'STLD',
#  'STE',
#  'SYK',
#  'SIVB',
#  'SYF',
#  'SNPS',
#  'SYY',
#  'TMUS',
#  'TROW',
#  'TTWO',
#  'TPR',
#  'TRGP',
#  'TGT',
#  'TEL',
#  'TDY',
#  'TFX',
#  'TER',
#  'TSLA',
#  'TXN',
#  'TXT',
#  'TMO',
#  'TJX',
#  'TSCO',
#  'TT',
#  'TDG',
#  'TRV',
#  'TRMB',
#  'TFC',
#  'TYL',
#  'TSN',
#  'USB',
#  'UDR',
#  'ULTA',
#  'UNP',
#  'UAL',
#  'UPS',
#  'URI',
#  'UNH',
#  'UHS',
#  'VLO',
#  'VTR',
#  'VRSN',
#  'VRSK',
#  'VZ',
#  'VRTX',
#  'VFC',
#  'VTRS',
#  'VICI',
#  'V',
#  'VNO',
#  'VMC',
#  'WAB',
#  'WBA',
#  'WMT',
#  'WBD',
#  'WM',
#  'WAT',
#  'WEC',
#  'WFC',
#  'WELL',
#  'WST',
#  'WDC',
#  'WRK',
#  'WY',
#  'WHR',
#  'WMB',
#  'WTW',
#  'GWW',
#  'WYNN',
#  'XEL',
#  'XYL',
#  'YUM',
#  'ZBRA',
#  'ZBH',
#  'ZION',
#  'ZTS']

# %%
len(tickers)
# Out:
# 503

# %%
# Collect the top 10 stocks of the S&P 500 to use as proxy for the SPY.AX ETF
# Note - hardcoding the stocks as there does not appear to be an easier way to 
# programitcally retrieve the S&P500 constituent stocks
spy_top10 = [
    'AAPL', 'MSFT', 'AMZN', 'TSLA', 'GOOGL', 'GOOG', 'NVDA', 'BRK.B', 'META', 'UNH'
]

# %%
# Retrieve credentials
load_dotenv()
alpaca_api_key = os.getenv("APCA-API-KEY-ID")
alpaca_secret_key = os.getenv("APCA-API-SECRET-KEY")
if not(alpaca_api_key) or not(alpaca_secret_key):
    print("Failed to load API credentials")

# %%
# Get the news for each
alpaca_endpoint = 'https://data.alpaca.markets/v1beta1/news'

alpaca_headers = {
    'Apca-Api-Key-Id': alpaca_api_key,
    'Apca-Api-Secret-Key': alpaca_secret_key
}
parameters = {
    'symbols': spy_top10[0],
    'start': pd.to_datetime("2022-07-01").strftime('%Y-%m-%d'),
    # 'start': '2021-12-28T00:00:00Z',
    'end': pd.to_datetime("2022-07-05").strftime('%Y-%m-%d'),
    # 'end': '2021-12-31T11:59:59Z',
    'limit': 50,
    'include_content': True,
}

response = requests.get(
    url = alpaca_endpoint,
    headers = alpaca_headers,
    params = parameters
)

response.raise_for_status()
# display(response.status)
display(response.json())
# Out:
# {'news': [{'author': 'Shanthi Rexaline',
#    'content': '<p>The first half of 2022 was nightmarish for the stock market, with fears of an imminent recession and supply chain disruptions working in the mind of investors.</p>\r\n\r\n<p>Tech stocks have invariably led the broader market in the past, be it a rally or a retreat, and this time was no exception. Despite fairly robust fundamental performances amid the trying backdrop, big techs came under significant selling pressure.</p>\r\n\r\n<p>Here&#39;s a look at how some of the high-profile tech stocks, commonly referred to using the acronym &quot;FAANG&quot; fared in the first half of the year:</p>\r\n\r\n<h3>The FAANG Stocks</h3>\r\n\r\n<p><strong>Meta Platforms, Inc. </strong>(NASDAQ:<a class="ticker" href="https://www.benzinga.com/stock/META#NASDAQ">META</a>)<br />\r\n<strong>Amazon, Inc. </strong>(NASDAQ:<a class="ticker" href="https://www.benzinga.com/stock/AMZN#NASDAQ">AMZN</a>)<br />\r\n<strong>Apple, Inc. </strong>(NASDAQ:<a class="ticker" href="https://www.benzinga.com/stock/AAPL#NASDAQ">AAPL</a>)<br />\r\n<strong>Netflix, Inc. </strong>(NASDAQ:<a class="ticker" href="https://www.benzinga.com/stock/NFLX#NASDAQ">NFLX</a>)<br />\r\n<strong>Alphabet, Inc. </strong>(NASDAQ:<a class="ticker" href="https://www.benzinga.com/stock/GOOGL#NASDAQ">GOOGL</a>) (NASDAQ:<a class="ticker" href="https://www.benzinga.com/stock/GOOG#NASDAQ">GOOG</a>)</p>\r\n\r\n<p><strong>No Winner Emerges: </strong> All the FAANG stocks incurred losses for the first half of the year, and more importantly, their losses were worse than the broader market. Apart from the market-wide pessimism, most were also left grappling with company-specific issues.</p>\r\n\r\n<p><strong>Meta: </strong> Meta, the parent of the flagship social media platform Facebook, is facing competitive pressure. China&#39;s Byte Dance-owned TikTok short video app has been giving its bigger rival a run for its money for some time now. Meta was left with no option but to&nbsp;launch its own version of the video clip format platform.</p>\r\n\r\n<p>As Meta introduced Reels within Instagram and then on Facebook per se, it was forced to promote it at the expense of its highly-monetized segments such as Feeds and Stories.</p>\r\n\r\n<p>Meta&#39;s ad revenues continue to take a hit from Apple&#39;s app tracking transparency crackdown. The privacy changes reportedly will impact Meta&#39;s revenue by about $13 billion in 2022.</p>\r\n\r\n<p><em>Related Link: <a href=" https://www.benzinga.com/analyst-ratings/analyst-color/22/04/26583422/chinas-covid-19-shutdown-is-beginning-to-bite-apple-says-analyst"> China&#39;s COVID-19 Shutdown Is Beginning to Bite Apple, Says Analyst </a></em></p>\r\n\r\n<p><strong>Amazon: </strong> For Amazon, it was the case of a tougher comparison against the pandemic years. The e-commerce giant benefited from the stay-at-home scenario that prevailed in 2020 and for much of 2021 when people splurged on online purchases.</p>\r\n\r\n<p>A <a href="https://www.benzinga.com/news/22/06/27563423/amazon-stock-begins-trading-on-split-adjusted-basis-what-investors-need-to-know"> stock split the company implemented in June </a> did little to reverse the negative sentiment toward the stock.</p>\r\n\r\n<p><strong>Apple: </strong> Apple continued to deliver, persisted with its shareholder return policy, and kept on rolling out superior products and services.<br />\r\nThe company is heavily reliant on China for the production of its hardware products, and so when COVID struck in the country, investors began discounting production shortfalls. China is also a key market for Apple from the demand perspective.</p>\r\n\r\n<p><strong>Netflix: </strong> Netflix was the worst-performing FAANG stock in the first half. The company reported a massive loss of net subscriber adds in the first quarter, a function of competition and saturated penetration in its key markets. The company outlined a few fixes, including a crackdown on password sharing and launching an ad-supported service. A ...
#    'created_at': '2022-07-03T19:45:56Z',
#    'headline': "A Forgettable First-Half: Here's How Apple And Other FAANGs Performed Amid Market Turbulence",
#    'id': 27942157,
#    'images': [{'size': 'large',
#      'url': 'https://cdn.benzinga.com/files/imagecache/2048x1536xUP/images/story/2022/07/03/faang.jpg'},
#     {'size': 'small',
#      'url': 'https://cdn.benzinga.com/files/imagecache/1024x768xUP/images/story/2022/07/03/faang.jpg'},
#     {'size': 'thumb',
#      'url': 'https://cdn.benzinga.com/files/imagecache/250x187xUP/images/story/2022/07/03/faang.jpg'}],
#    'source': 'benzinga',
#    'summary': 'The first half of 2022 was nightmarish for the stock market, with fears of an imminent recession and supply chain disruptions working in the mind of investors.',
#    'symbols': ['AAPL',
#     'AMD',
#     'AMZN',
#     'GOOG',
#     'GOOGL',
#     'META',
#     'MSFT',
#     'NFLX',
#     'NVDA'],
#    'updated_at': '2022-07-03T19:45:56Z',
#    'url': 'https://www.benzinga.com/general/education/22/07/27942157/a-forgettable-first-half-heres-how-apple-and-other-faangs-performed-amid-market-turbulence'},
#   {'author': 'Shanthi Rexaline',
#    'content': '<p>Those Apple loyalists who plan to buy the Apple Watch Series 8 when it launches this fall can look forward to an added utility.</p>\r\n\r\n<p>Apple Watch Series 8 will have body-temperature detection as a new feature in both the standard option and a new rugged edition targeting extreme sports athletes, Bloomberg columnist <strong>Mark Gurman </strong> said in his Power-On weekly newsletter.</p>\r\n\r\n<p>He had earlier in April hinted at this feature becoming a possibility if it passes internal testing.</p>\r\n\r\n<p>&quot;I now believe the feature is a go&quot; Gurman said.</p>\r\n\r\n<p>Noted Apple analyst <strong>Ming-Chi Kuo </strong> has also raised the possibility of this feature making its appearance in the <a href=" https://www.benzinga.com/news/22/05/26922944/will-apples-upcoming-watch-8-let-you-measure-your-body-temperature"> upcoming Watch model </a></p>\r\n\r\n<p><em>Related Link: <a href=" https://www.benzinga.com/analyst-ratings/analyst-color/22/06/27897326/apple-analyst-says-this-is-cupertinos-unique-advantage-over-other-tech-stalwarts"> Apple Analyst Says This Is Cupertino&#39;s Unique Advantage Over Other Tech Giants </a></em></p>\r\n\r\n<p>Gurman noted that the lower-end SE version, set to be launched this year, may not have the capability.</p>\r\n\r\n<p>The body temperature measurement, according to Gurman, may not give a specific reading just as our forehead or wrist thermometer but should be able to tell you if it thinks you have a fever.</p>\r\n\r\n<p>It could then recommend you to either visit your doctor or use a dedicated thermometer, he added.</p>\r\n\r\n<p>Gurman does not expect any other major hardware changes. There have been talks of updated displays in the new high-end models, he added.</p>\r\n\r\n<p>Apple closed Friday&#39;s session at $138.93, up 1.62%, according to <a href="https://benzinga.grsm.io/register174"> Benzinga Pro data.</a></p>\r\n',
#    'created_at': '2022-07-03T18:46:04Z',
#    'headline': "Apple Watch Series 8 Will Be Able To Tell If You're Sick With This New Detection Feature: Report",
#    'id': 27942229,
#    'images': [{'size': 'large',
#      'url': 'https://cdn.benzinga.com/files/imagecache/2048x1536xUP/images/story/2022/07/03/apple_watch3.jpg'},
#     {'size': 'small',
#      'url': 'https://cdn.benzinga.com/files/imagecache/1024x768xUP/images/story/2022/07/03/apple_watch3.jpg'},
#     {'size': 'thumb',
#      'url': 'https://cdn.benzinga.com/files/imagecache/250x187xUP/images/story/2022/07/03/apple_watch3.jpg'}],
#    'source': 'benzinga',
#    'summary': 'Those Apple loyalists who plan to buy the Apple Watch Series 8 when it launches this fall can look forward to an added utility.\n\nApple Watch Series 8 will have body-temperature detection as a new feature in both the standard option and a new rugged edition targeting extreme sports athletes, Bloomberg columnist Mark Gurman  said in his Power-On weekly newsletter.',
#    'symbols': ['AAPL'],
#    'updated_at': '2022-07-03T18:46:05Z',
#    'url': 'https://www.benzinga.com/news/22/07/27942229/apple-watch-series-8-can-tell-if-you-have-fever-report'},
#   {'author': 'Michael Cohen',
#    'content': '<p><em>Benzinga reviews this weekend&#39;s top stories on&nbsp;<a href="http://www.benzinga.com/topic/barron-s" target="_blank">Barron&#39;s</a>, for additional information on the latest market news,&nbsp;<a href="https://benzinga.grsm.io/news1865">Benzinga Pro</a>&nbsp;offers&nbsp;a 24/7 news feed, live chat and charting software.&nbsp;</em></p>\r\n\r\n<p>&quot;<a href="https://www.barrons.com/articles/best-income-investments-bonds-yields-51656713799?mod=hp_HERO">Yields Are Above 8%. It&rsquo;s Time to
NASDAQ:<a class="ticker" href="https://www.benzinga.com/stock/AAPL#NASDAQ">AAPL</a>) reduced its iPhone 14 chip orders to <strong>Taiwan Semiconductor Manufacturing Company Limited </strong>(NYSE:<a class="ticker" href="https://www.benzinga.com/stock/TSM#NYSE">TSM</a>), suggesting the tech giant has lowered its production forecast for the upcoming <a href=" https://www.benzinga.com/news/22/04/26779282/camera-improvements-screen-size-overhaul-rudimentary-satellite-connectivity-heres-what-this-apple-sp"> iPhone 14 </a>by 10%, according to a DigiTimes report.</p>\r\n\r\n<p>Prominent Apple analyst,&nbsp;<strong>Ming-Chi Kuo&nbsp;</strong>has allayed concerns about a scale-back.</p>\r\n\r\n<p><strong>Kuo Calms Nerves Regarding iPhone 14: </strong> The <strong>TFI International Securities </strong> analyst said he maintains his second-half 2022 shipment forecast of about 100 million units for iPhone 14 and 90 million units for components and electronic manufacturing services supplies.<br />\r\nSlight adjustments in iPhone shipment forecasts, meaning single-digit increases or decreases, are common, before launching new models, the analyst said. Apple doesn&#39;t make marked changes like this, he added.</p>\r\n\r\n<p>&quot;If a supply chain issue causes a significant change in the shipment plan of the new iPhones before mass production, Apple usually postpones the orders instead of cutting them,&quot; Kuo said.</p>\r\n\r\n<p><em>Related Link: <a href=" https://www.benzinga.com/analyst-ratings/analyst-color/22/04/26705655/apple-analyst-says-iphone-14-will-come-with-major-camera-improvements-what-you-need"> Apple Analyst Says iPhone 14 Will Come With Major Camera Improvements: What You Need to Know </a></em></p>\r\n\r\n<p><strong>China Demand Strong: </strong> Demand for the iPhone 14 in the Chinese market may be stronger than that of the iPhone 13, Kuo said in a tweet on Thursday.</p>\r\n\r\n<p>Chinese distributors/retailers/scalpers are paying the highest prepaid deposit ever for the iPhone 14 to ensure sufficient supply, the analyst noted. Prepaid deposits&nbsp;for the iPhone 14 are&nbsp;significantly higher than the iPhone 13 and even twice as high in some areas, he added.</p>\r\n\r\n<p>Apple closed Friday&#39;s session 1.62% higher at $138.93, according to <a href="https://benzinga.grsm.io/register174"> Benzinga Pro.</a></p>\r\n',
#    'created_at': '2022-07-02T16:27:50Z',
#    'headline': "Rumors Of iPhone 14 Production Cuts Surface: Why Prominent Apple Analyst Isn't Concerned",
#    'id': 27939798,
#    'images': [{'size': 'large',
#      'url': 'https://cdn.benzinga.com/files/imagecache/2048x1536xUP/images/story/2022/07/02/iphone8.jpg'},
#     {'size': 'small',
#      'url': 'https://cdn.benzinga.com/files/imagecache/1024x768xUP/images/story/2022/07/02/iphone8.jpg'},
#     {'size': 'thumb',
#      'url': 'https://cdn.benzinga.com/files/imagecache/250x187xUP/images/story/2022/07/02/iphone8.jpg'}],
#    'source': 'benzinga',
#    'summary': 'Apple, Inc.',
#    'symbols': ['AAPL', 'TSM'],
#    'updated_at': '2022-07-02T16:27:51Z',
#    'url': 'https://www.benzinga.com/analyst-ratings/analyst-color/22/07/27939798/as-rumors-of-iphone-14-production-cuts-surface-prominent-apple-analyst-has-this-to-'},
#   {'author': 'Michael Horton',
#    'content': '',
#    'created_at': '2022-07-01T20:03:15Z',
#    'headline': 'Top 15 Trending Stocks On WallStreetBets As Of Friday, July 1, 2022 (Via Swaggy Stocks)',
#    'id': 27936648,
#    'images': [],
#    'source': 'benzinga',
#    'summary': '',
#    'symbols': ['AAPL',
#     'AMD',
#     'AMZN',
#     'GLD',
#     'GM',
#     'GME',
#     'JPM',
#     'META',
#     'MU',
#     'NVDA',
#     'QQQ',
#     'SOXL',
#     'TQQQ',
#     'TSLA',
#     'WISH'],
#    'updated_at': '2022-07-01T20:03:16Z',
#    'url': 'https://www.benzinga.com/trading-ideas/22/07/27936648/top-15-trending-stocks-on-wallstreetbets-as-of-friday-july-1-2022-via-swaggy-stocks'},
strong> (NASDAQ:<a class="ticker" href="https://www.benzinga.com/stock/ENPH#NASDAQ ...
#    'created_at': '2022-07-01T19:53:38Z',
#    'headline': "'How Do You Not Like Apple?': How CNBC's Todd Gordon Is Investing In A Volatile Market",
#    'id': 27935696,
#    'images': [{'size': 'large',
#      'url': 'https://cdn.benzinga.com/files/imagecache/2048x1536xUP/images/story/2022/07/01/shutterstock_1870904317.jpg'},
#     {'size': 'small',
#      'url': 'https://cdn.benzinga.com/files/imagecache/1024x768xUP/images/story/2022/07/01/shutterstock_1870904317.jpg'},
#     {'size': 'thumb',
#      'url': 'https://cdn.benzinga.com/files/imagecache/250x187xUP/images/story/2022/07/01/shutterstock_1870904317.jpg'}],
#    'source': 'benzinga',
#    'summary': 'Todd Gordon, CNBC contributor and founder of New Age Wealth Advisors, joined Benzinga&#39;s PreMarket Prep show on Friday morning.\n\nGordon discussed the S&amp;P 500 market weakness so far in 2022 and how he is positioning his clients&#39; money heading into the second half of the year.',
#    'symbols': ['AAPL',
#     'AMD',
#     'ENPH',
#     'INTC',
#     'LYV',
#     'META',
#     'MSFT',
#     'NVDA',
#     'SPY',
#     'TSLA'],
#    'updated_at': '2022-07-01T19:53:38Z',
#    'url': 'https://www.benzinga.com/analyst-ratings/analyst-color/22/07/27935696/how-do-you-not-like-apple-how-cnbcs-todd-gordon-is-investing-in-a-volatile-market'},
#   {'author': 'Anusuya Lahiri',
#    'content': '<p>Global&nbsp;<strong>Microsoft Corp</strong>&nbsp;(NASDAQ:<a class="ticker" href="https://www.benzinga.com/stock/MSFT#NASDAQ">MSFT</a>) Azure data centers are operating with limited server capacity amid a global supply shortage,&nbsp;<a class="editor-rtfLink" href="https://www.theinformation.com/articles/microsoft-cloud-computing-system-suffering-from-global-shortage?utm_source=organic&amp;utm_content=headline&amp;utm_medium=awarenessbar&amp;utm_campaign=AB_post" style="color:#4a6ee0; background:transparent; margin-top:0pt; margin-bottom:0pt" target="_blank">the Information reports</a>.</p>\r\n\r\n<p>Over two dozen data centers operated with limited server capacity available to customers based on two current Microsoft managers and an engineer who works for a significant customer.</p>\r\n\r\n<p>The server capacity at more than half a dozen Azure data centers will likely remain limited until early 2023. It included a facility in central Washington state and others in Europe and Asia.</p>\r\n\r\n<p>Microsoft&#39;s struggle to fill its data centers with hardware comes after a surge in cloud demand at the outset of the pandemic.</p>\r\n\r\n<p>In April 2020, CEO Satya Nadella acknowledged two years of digital transformation in two months due to the pandemic. He saw an immediate surge in demand and systemic structural changes across every solution area. The demand surge led to several minor outages of Azure services. However, it is hard to ascertain the link to the usage spike.</p>\r\n\r\n<p><strong>Alphabet Inc&nbsp;</strong>(NASDAQ:<a class="ticker" href="https://www.benzinga.com/stock/GOOG#NASDAQ">GOOG</a>) (NASDAQ:<a class="ticker" href="https://www.benzinga.com/stock/GOOGL#NASDAQ">GOOGL</a>) Google,&nbsp;<strong>Amazon.com Inc</strong>&nbsp;(NASDAQ:<a class="ticker" href="https://www.benzinga.com/stock/AMZN#NASDAQ">AMZN</a>) Amazon Web Services, and other popular websites witnessed disruptions in June due to a&nbsp;<a class="editor-rtfLink" href="https://www.benzinga.com/news/22/06/27788910/early-morning-internet-woes-discord-coinbase-google-suffer-outages-as-cloudflare-identifies-issue-wi" style="color:#4a6ee0; background:transparent; margin-top:0pt; margin-bottom:0pt" target="_blank">widespread outage at</a>&nbsp;<strong>Cloudflare, Inc&nbsp;</strong>(NYSE:<a class="ticker" href="https://www.benzinga.com/stock/NET#NYSE">NET</a>).</p>\r\n\r\n<p>In December, AWS suffered its third major outage in a matter of weeks last month, affecting millions of people,&nbsp;<a class="editor-rtfLink" href="https://www.forbes.com/sites/davidjeans/2022/01/27/amazon-aws-outages-multi-cloud/?sh=3557b6bf4cec" style="color:#4a6ee0; background:transparent; margin-top:0pt; margin-bottom:0pt" target="_blank">Forbes reported</a>. It led to the clients diversifying the risks by securing access to multiple cloud providers like Microsoft.</p>\r\n\r\n<p><strong>Apple Inc</strong>&nbsp;(NASDAQ:<a class="ticker" href="https://www.benzinga.com/stock/AAPL#NASDAQ">AAPL</a>) iCloud, Microsoft Azure, and Google Cloud were among the technology vendors to experience major cloud outages in 2022,&nbsp;<a class="editor-rtfLink" href="https://www.crn.com/news/cloud/the-10-biggest-cloud-outages-of-2022-so-far-" style="color:#4a6ee0; background:transparent; margin-top:0pt; margin-bottom:0pt" target="_blank">CRN reported</a></p>\r\n\r\n<p>The issues vendors have experienced from cut fiber cables and changes in coding to an air system shutdown in a data center. Experts held the era of cloud computing responsible for the more frequent outages but with less severity.</p>\r\n\r\n<p><strong>Price Action:</strong>&nbsp;MSFT shares traded higher by 0.80% at $258.89 on the last check Friday.</p>\r\n\r\n<p><em>Photo by Rainer Stropek via Flickr</em></p>\r\n ',
#    'created_at': '2022-07-01T19:27:38Z',
#    'headline': 'Microsoft Azure Data Centers are Operating With Limited Server Capacity: Report',
#    'id': 27935265,
#    'images': [{'size': 'large',
#      'url': 'https://cdn.benzinga.com/files/imagecache/2048x1536xUP/images/story/2022/07/01/azure-rainer_stropek_via_flickr.jpg'},
#     {'size': 'small',
#      'url': 'https://cdn.benzinga.com/files/imagecache/1024x768xUP/images/story/2022/07/01/azure-rainer_stropek_via_flickr.jpg'},
#     {'size': 'thumb',
#      'url': 'https://cdn.benzinga.com/files/imagecache/250x187xUP/images/story/2022/07/01/azure-rainer_stropek_via_flickr.jpg'}],
#    'source': 'benzinga',
#    'summary': 'Global\xa0Microsoft Corp\xa0(NASDAQ: MSFT) Azure data centers are operating with limited server capacity amid a global supply shortage,\xa0',
#    'symbols': ['AAPL', 'AMZN', 'GOOG', 'GOOGL', 'MSFT', 'NET'],
#    'updated_at': '2022-07-01T19:27:39Z',
#    'url': 'https://www.benzinga.com/news/22/07/27935265/microsoft-azure-data-centers-operating-with-limited-server-capacity-report'},
#   {'author': 'Benzinga Insights',
#    'content': '<p>&nbsp;</p>\r\n\r\n<p>This whale alert can help traders discover the next big trading opportunities.</p>\r\n\r\n<p>Whales are entities with large sums of money and we track their transactions here at Benzinga on our options activity scanner.</p>\r\n\r\n<p>Traders will search for circumstances when the market estimation of an option diverges heavily from its normal worth. High amounts of trading activity could push option prices to exaggerated or underestimated levels.</p>\r\n\r\n<p>Here&#39;s the list of options activity happening in today&#39;s session:</p>\r\n\r\n<table>\r\n\t<thead>\r\n\t\t<tr>\r\n\t\t\t<th><strong>Symbol</strong></th>\r\n\t\t\t<th><strong>PUT/CALL</strong></th>\r\n\t\t\t<th><strong>Trade Type</strong></th>\r\n\t\t\t<th><strong>Sentiment</strong></th>\r\n\t\t\t<th><strong>Exp. Date</strong></th>\r\n\t\t\t<th><strong>Strike Price</strong></th>\r\n\t\t\t<th><strong>Total Trade Price</strong></th>\r\n\t\t\t<th><strong>Open Interest</strong></th>\r\n\t\t\t<th><strong>Volume</strong></th>\r\n\t\t</tr>\r\n\t</thead>\r\n\t<tbody>\r\n\t\t<tr>\r\n\t\t\t<td>AAPL</td>\r\n\t\t\t<td>CALL</td>\r\n\t\t\t<td>TRADE</td>\r\n\t\t\t<td>BULLISH</td>\r\n\t\t\t<td>07/08/22</td>\r\n\t\t\t<td>$137.00</td>\r\n\t\t\t<td>$50.0K</td>\r\n\t\t\t<td>2.3K</td>\r\n\t\t\t<td>10.5K</td>\r\n\t\t</tr>\r\n\t\t<tr>\r\n\t\t\t<
td>\r\n\t\t</tr>\r\n\t\t<tr>\r\n\t\t\t<td>TXN</td>\r\n\t\t\t<td>PUT</td>\r\n\t\t\t<td>SWEEP</td>\r\n\t\t\t<td>BULLISH</td>\r\n\t\t\t<td>07/15/22</td>\r\n\t\t\t<td>$140.00</td>\r\n\t\t\t<td>$29.8K</td>\r\n\t\t\t<td>4.6K</td>\r\n\t\t\t<td>243</td>\r\n\t\t</tr>\r\n\t\t<tr>\r\n\t\t\t<td>U</td>\r\n\t\t\t<td>PUT</td>\r\n\t\t\t<td>SWEEP</td>\r\n\t\t\t<td>BULLISH</td>\r\n\t\t\t<td>08/12/22</td>\r\n\t\t\t<td>$40.00</td>\r\n\t\t\t<td>$38.3K</td>\r\n\t\t\t<td>0</td>\r\n\t\t\t<td>191</td>\r\n\t\t</tr>\r\n\t</tbody>\r\n</table>\r\n\r\n<h2>Explanation</h2>\r\n\r\n<p>These itemized elaborations have been created using the accompanying table.</p>\r\n\r\n<p>&bull; Regarding <strong>AAPL</strong> (NASDAQ:<a class="ticker" href="https://www.benzinga.com/stock/AAPL#NASDAQ">AAPL</a>), we observe a <strong>call</strong> option <strong>trade</strong> with <strong>bullish</strong> sentiment. It expires in 7 day(s) on <strong>July 8, 2022</strong>. Parties traded <strong>200</strong> contract(s) at a <s ...
#    'created_at': '2022-07-01T18:44:40Z',
#    'headline': "10 Information Technology Stocks With Whale Alerts In Today's Session",
#    'id': 27935112,
#    'images': [{'size': 'large',
#      'url': 'https://cdn.benzinga.com/files/imagecache/2048x1536xUP/images/story/2022/options_image_1483.jpeg'},
#     {'size': 'small',
#      'url': 'https://cdn.benzinga.com/files/imagecache/1024x768xUP/images/story/2022/options_image_1483.jpeg'},
#     {'size': 'thumb',
#      'url': 'https://cdn.benzinga.com/files/imagecache/250x187xUP/images/story/2022/options_image_1483.jpeg'}],
#    'source': 'benzinga',
#    'summary': '\xa0\n\nThis whale alert can help traders discover the next big trading opportunities.\n\nWhales are entities with large sums of money and we track their transactions here at Benzinga on our options activity scanner.',
#    'symbols': ['AAPL',
#     'AMD',
#     'AVGO',
#     'DDOG',
#     'NVDA',
#     'PYPL',
#     'TSM',
#     'TXN',
#     'U',
#     'ZS'],
#    'updated_at': '2022-07-01T18:44:41Z',
#    'url': 'https://www.benzinga.com/markets/options/22/07/27935112/10-information-technology-stocks-with-whale-alerts-in-todays-session'},
#   {'author': 'Charles Gross',
#    'content': '',
#    'created_at': '2022-07-01T17:22:22Z',
#    'headline': 'Top Wall Street Bets Mentions for Friday July 1, 2022 Since 9:30 AM ET Market Open: TSLA, AMD, GME, NVDA, SOXL, BBBY, META, AAPL, AMZN, ZIM',
#    'id': 27934925,
#    'images': [],
#    'source': 'benzinga',
#    'summary': '',
#    'symbols': ['AAPL',
#     'AMD',
#     'AMZN',
#     'BBBY',
#     'GME',
#     'META',
#     'NVDA',
#     'SOXL',
#     'TSLA',
#     'ZIM'],
#    'updated_at': '2022-07-01T17:22:22Z',
#    'url': 'https://www.benzinga.com/news/22/07/27934925/top-wall-street-bets-mentions-for-friday-july-1-2022-since-9-30-am-et-market-open-tsla-amd-gme-nvda'},
#   {'author': 'Henry Khederian',
#    'content': '<p><strong>Vertex Pharmaceuticals Incorporated</strong> (NASDAQ:<a class="ticker" href="https://www.benzinga.com/stock/VRTX#NASDAQ">VRTX</a>) creates new possibilities via&nbsp;medicine to cure diseases and improve people&#39;s lives, and over the past year, marked gains in investors&rsquo; portfolios.</p>\r\n\r\n<p>Since July 2021, Vertex Pharmaceuticals stock&rsquo;s one-year return has outperformed several of the world&rsquo;s most popular tech and consumer discretionary stocks: <strong>Tesla Inc.</strong> (NASDAQ:<a class="ticker" href="https://www.benzinga.com/stock/TSLA#NASDAQ">TSLA</a>)&nbsp;<strong>Apple Inc</strong> (NASDAQ:<a class="ticker" href="https://www.benzinga.com/stock/AAPL#NASDAQ">AAPL</a>), <strong>Starbucks Corporation</strong> (NASDAQ:<a class="ticker" href="https://www.benzinga.com/stock/SBUX#NASDAQ">SBUX</a>), <strong>NVIDIA Corporation</strong> (NASDAQ:<a class="ticker" href="https://www.benzinga.com/stock/NVDA#NASDAQ">NVDA</a>) and <strong>Microsoft Corporation</strong> (NASDAQ:<a class="ticker" href="https://www.benzinga.com/stock/MSFT#NASDAQ">MSFT</a>).</p>\r\n\r\n<p>Vertex Pharmaceuticals is a global biotechnology company that discovers and develops small-molecule drugs for the treatment of serious diseases. Its key drugs are Kalydeco, Orkambi, Symdeko&nbsp;and Trikafta/Kaftrio.</p>\r\n\r\n<p>Vertex was founded in 1989 and is headquartered in Boston, Massachusetts.</p>\r\n\r\n<p><strong>Here&#39;s how the returns break down from July 2021 to the&nbsp;present:&nbsp;</strong></p>\r\n\r\n<ul>\r\n\t<li>Tesla is down&nbsp;from $677.92 to $669.11 for a return of -1.30%</li>\r\n\t<li>Starbucks is down from $113.41 to $77.87 for a return of -31.34%</li>\r\n\t<li>Microsoft is&nbsp;down from $271.60 to $255.52 for a return of -5.92%</li>\r\n\t<li>Nvidia is down from $202.12 to $145.74 for a return of -27.89%</li>\r\n\t<li>Apple is down&nbsp;from $137.27 to $135.94 for a return of -0.97%</li>\r\n\t<li><strong>And finally, Vertex is up from $202.21 to $282.35 for a return of 39.63%</strong></li>\r\n</ul>\r\n\r\n<p>&nbsp;</p>\r\n ',
#    'created_at': '2022-07-01T14:45:00Z',
#    'headline': 'This Biopharmaceutical Company Has A Better 1-Year Return Than Tesla, Apple, Starbucks, Nvidia And Microsoft',
#    'id': 25375757,
#    'images': [{'size': 'large',
#      'url': 'https://cdn.benzinga.com/files/imagecache/2048x1536xUP/images/story/2012/chemistry-lab-experiment-3005692_1.png'},
#     {'size': 'small',
#      'url': 'https://cdn.benzinga.com/files/imagecache/1024x768xUP/images/story/2012/chemistry-lab-experiment-3005692_1.png'},
#     {'size': 'thumb',
#      'url': 'https://cdn.benzinga.com/files/imagecache/250x187xUP/images/story/2012/chemistry-lab-experiment-3005692_1.png'}],
#    'source': 'benzinga',
#    'summary': 'Vertex Pharmaceuticals Incorporated (NASDAQ: VRTX) creates new possibilities via\xa0medicine to cure diseases and improve people&#39;s lives, and over the past year, marked gains in investors’ portfolios.',
#    'symbols': ['AAPL', 'MSFT', 'NVDA', 'SBUX', 'TSLA', 'VRTX'],
#    'updated_at': '2022-07-01T14:46:16Z',
#    'url': 'https://www.benzinga.com/general/biotech/22/02/25375757/this-biopharmaceutical-company-has-a-better-year-return-than-apple-starbucks-nvidia-and-micros'},
#   {'author': 'Anusuya Lahiri',
#    'content': '<p>Chipmaking stocks are bleeding post&nbsp;<strong>Micron Technology, Inc&#39;s</strong>&nbsp;(NASDAQ:<a class="ticker" href="https://www.benzinga.com/stock/MU#NASDAQ">MU</a>)&nbsp;<a class="editor-rtfLink" href="https://www.benzinga.com/news/earnings/22/06/27923459/after-hours-alert-why-micron-stock-is-falling" style="color:#4a6ee0; background:transparent; margin-top:0pt; margin-bottom:0pt" target="_blank">cautious Q4 guidance</a>.&nbsp;</p>\r\n\r\n<p><strong>Piper Sandler</strong>&nbsp;saw DRAM, and NAND&nbsp;<a class="editor-rtfLink" href="https://www.benzinga.com/news/22/06/27920453/piper-sandler-sees-dram-nand-pricing-decline-set-to-weigh-on-micron-read-why" style="color:#4a6ee0; background:transparent; margin-top:0pt; margin-bottom:0pt" target="_blank">pricing decline, affecting</a>&nbsp;Micron as mobile and notebook end-markets face continued weakness based on inSpectrum&#39;s June monthly memory contract pricing data.</p>\r\n\r\n<p>Piper Sandler also shared how semiconductor equipment stocks may become range-bound in a decelerating or declining memory CAPEX environment.</p>\r\n\r\n<p>It pointed out&nbsp;<strong>Lam Research Corp</strong>&nbsp;(NASDAQ:<a class="ticker" href="https://www.benzinga.com/stock/LRCX#NASDAQ">LRCX</a>) with higher relative exposure to memory CAPEX, followed by&nbsp;<strong>Applied Materials, Inc</strong>&nbsp;(NASDAQ:<a class="ticker" href="https://www.benzinga.com/stock/AMAT#NASDAQ">AMAT</a>),&nbsp;<strong>KLA Corp</strong>&nbsp;(NASDAQ:<a class="ticker" href="https://www.benzinga.com/stock/KLAC#NASDAQ">KLAC</a>), and&nbsp;<strong>ASML Holding N.V.</strong>&nbsp;(NASDAQ:<a class="ticker" href="https://www.benzinga.com/stock/ASML#NASDAQ">ASML</a>).</p>\r\n\r\n<p>Piper Sandler&nbsp;<a class="editor-rtfLink" href="https://www.benzinga.com/news/22/06/27543743/micron-shares-drop-on-this-analyst-downgrade" style="color:#4a6ee0; background:transparent; margin-top:0pt; margin-bottom:0pt" target="_blank">had downgraded</a>&nbsp;Micron, citing its dependence on DRAM, battling price declines for most configurations, and significant exposure to consumer-like markets such as PCs and mobile, which get hammered during an economic slowdown.</p>\r\n\r\n<p>Mizuho also shared&nbsp;<a class="editor-rtfLink" href="https://www.benzinga.com/news/22/06/27797727/heres-why-this-analyst-believes-negative-sentiment-macro-as-an-opportunity-to-step-in-for-micron-wes" style="color:#4a6ee0; background:transparent; margin-top:0pt; margin-bottom:0pt" target="_blank">a similar opinion</a>.</p>\r\n\r\n<p>Earlier this month,&nbsp;<strong>Advanced Micro Devices, Inc</strong>&nbsp;(NASDAQ:<a class="ticker" href="https://www.benzinga.com/stock/AMD#NASDAQ">AMD</a>) warned against a&nbsp;<a class="editor-rtfLink" href="https://www.benzinga.com/analyst-ratings/analyst-color/22/04/26417167/rosenblatt-analyst-explains-how-amd-stock-weakness-is-buying-opportunity" style="color:#4a6ee0; background:transparent; margin-top:0pt; margin-bottom:0pt" target="_blank">slowdown in the PC</a>&nbsp;market after two solid years amid the pandemic.</p>\r\n\r\n<p><a class="editor-rtfLink" href="https://www.benzinga.com/news/22/06/27912100/nvidia-apple-microsoft-others-set-to-lose-as-gartner-predicts-demand-softness-for-smartphones-pcs-in" style="color:#4a6ee0; background:transparent; margin-top:0pt; margin-bottom:0pt" target="_blank">Gartner also shared</a>&nbsp;how China&#39;s economic slowdown and inflation-led drop in consumer spending will likely weigh on the global shipments of computers and smartphones in 2022. All of which will affect&nbsp;<a class="editor-rtfLink" href="https://www.benzinga.com/government/22/03/26390713/read-how-apple-plans-to-beat-chip-crisis-and-continue-to-score-in-china" style="color:#4a6ee0; background:transparent; margin-top:0pt; margin-bottom:0pt" target="_blank">companies ranging from</a>&nbsp;<strong>Nvidia Corp</strong>&nbsp;(NASDAQ:&nbsp;<a class="editor-rtfLink" href="https://www.benzinga.com/stock/nvd ...
#    'created_at': '2022-07-01T13:12:09Z',
#    'headline': "Here's Why Micron, TSMC, AMD, Nvidia, Qualcomm And Other Chipmakers Are Trading Lower Premarket",
#    'id': 27931071,
#    'images': [{'size': 'large',
#      'url': 'https://cdn.benzinga.com/files/imagecache/2048x1536xUP/images/story/2022/07/01/micron_crucial_ssd_mx300_525gb-8478.jpg'},
#     {'size': 'small',
#      'url': 'https://cdn.benzinga.com/files/imagecache/1024x768xUP/images/story/2022/07/01/micron_crucial_ssd_mx300_525gb-8478.jpg'},
#     {'size': 'thumb',
#      'url': 'https://cdn.benzinga.com/files/imagecache/250x187xUP/images/story/2022/07/01/micron_crucial_ssd_mx300_525gb-8478.jpg'}],
#    'source': 'benzinga',
#    'summary': 'Chipmaking stocks are bleeding post\xa0Micron Technology, Inc&#39;s\xa0(NASDAQ: MU)\xa0',
#    'symbols': ['AAPL',
#     'AMAT',
#     'AMD',
#     'ASML',
#     'KLAC',
#     'LRCX',
#     'MSFT',
#     'MU',
#     'NVDA',
#     'QCOM',
#     'TSM',
#     'UMC',
#     'WDC'],
#    'updated_at': '2022-07-01T13:12:10Z',
#    'url': 'https://www.benzinga.com/news/22/07/27931071/heres-why-micron-asml-tsmc-amd-nvidia-qualcomm-and-other-chipmakers-are-trading-lower-premarket'},
#   {'author': 'Akanksha Bakshi',
# ...
#    'created_at': '2022-07-01T09:28:58Z',
#    'headline': 'Apple CarPlay Users Could Soon Get To Buy Gas Right Off Their Dashboard',
#    'id': 27927887,
#    'images': [{'size': 'large',
#      'url': 'https://cdn.benzinga.com/files/imagecache/2048x1536xUP/images/story/2022/07/01/shutterstock_1097457164.jpg'},
#     {'size': 'small',
#      'url': 'https://cdn.benzinga.com/files/imagecache/1024x768xUP/images/story/2022/07/01/shutterstock_1097457164.jpg'},
#     {'size': 'thumb',
#      'url': 'https://cdn.benzinga.com/files/imagecache/250x187xUP/images/story/2022/07/01/shutterstock_1097457164.jpg'}],
#    'source': 'benzinga',
#    'summary': 'Apple Inc\xa0(NASDAQ:\xa0AAPL) could allow its\xa0CarPlay\xa0users to purchase gasoline directly from their vehicle’s dashboard as early as this fall.',
#    'symbols': ['AAPL', 'DINO', 'TSLA'],
#    'updated_at': '2022-07-01T09:28:58Z',
#    'url': 'https://www.benzinga.com/news/22/07/27927887/apple-could-soon-allow-carplay-customers-to-buy-gas-directly-from-dashboard-report'},
#   {'author': 'Lisa Levin',
#    'content': '<p><strong>Pre-open movers</strong></p>\r\n\r\n<p>U.S. stock futures traded slightly lower in early pre-market trade on Friday after the Wall Street recorded its worst first half in over 50 years.</p>\r\n\r\n<p>The Markit PMI manufacturing data for June will be released at 9:45 a.m. ET, while the ISM manufacturing index for June and data on construction spending for May will be released at 10:00 a.m. ET.</p>\r\n\r\n<p><a href="https://www.benzinga.com/news/earnings/22/07/27928194/micron-akebia-therapeutics-and-3-stocks-to-watch-heading-into-friday"><em>Check out this: Micron, Akebia Therapeutics And 3 Stocks To Watch Heading Into Friday </em></a></p>\r\n\r\n<p>Futures for the Dow Jones Industrial Average dipped 54 points to 30,727.00 while the Standard &amp; Poor&rsquo;s 500 index futures fell 6.25 points to 3,783.25. Futures for the Nasdaq index fell 18 points to 11,511.50.</p>\r\n\r\n<p><a href="https://www.benzinga.com/investing/global-oil-storage-trends/">Oil prices </a>traded higher as Brent crude futures rose 1.7% to trade at $110.93 per barrel, while US WTI crude futures rose 1.5% to trade at $107.38 a barrel. The Baker Hughes North American rig count report for the latest week is scheduled for release at 1:00 p.m. ET.</p>\r\n\r\n<p>The U.S. has the highest number of COVID-19 cases and deaths in the world, with total infections in the country exceeding 89,360,080 with around 1,042,670 deaths. India reported a total of at least 43,471,280 confirmed cases, while Brazil confirmed over 32,358,450 cases.</p>\r\n\r\n<p>&nbsp;</p>\r\n\r\n<p><strong>A Peek Into Global Markets</strong></p>\r\n\r\n<p>European markets were higher today. The STOXX Europe 600 Index gained 0.1%, London&rsquo;s FTSE 100 rose 0.1% while Spain&rsquo;s IBEX 35 Index rose 1.1%. The French CAC 40 Index rose 0.5%, while German DAX gained 0.4%. The S&amp;P Global manufacturing PMI for France declined to 51.4 in June from 54.6 in the previous month, while UK manufacturing PMI dropped to a two-year low of 52.8 in June. The S&amp;P Global Eurozone manufacturing PMI declined to 52.1 in June from 54.6 in the previous month, while Italian manufacturing PMI declined to 50.9 from 50.1. The S&amp;P Global/BME manufacturing PMI for Germany dropped to 52 in June from 54.8 a month ago, while Spanish manufacturing PMI dipped to 52.6 from 53.8.</p>\r\n\r\n<p>Asian markets traded lower today. Japan&rsquo;s Nikkei 225 fell 1.73%, China&rsquo;s Shanghai Composite fell 0.32% and Hong Kong&rsquo;s Hang Seng Index fell 0.62%. Australia&rsquo;s S&amp;P/ASX 200 fell 0.4%, while India&rsquo;s S&amp;P BSE Sensex fell 0.8%. The S&amp;P Global Indian manufacturing index declined to 53.9 in June from 54.6 in May, while the Caixin China&rsquo;s general manufacturing PMI rose to 51.7 from 48.1. The au Jibun Bank Japanese manufacturing PMI fell to 52.7 in June from 53.3 a month ago, while unemployment rate rose to 2.6% in May from April&#39;s figure of 2.5%. Australian manufacturing PMI rose to 56.2 in June from 55.7 in May.</p>\r\n\r\n<p><br />\r\n<strong>Broker Recommendation</strong></p>\r\n\r\n<p>B of A Securities downgraded <strong> Duck Creek Technologies, Inc. </strong> (NASDAQ:<a class="ticker" href="https://www.benzinga.com/stock/DCT#NASDAQ">DCT</a>) from Buy to Neutral and announced a $16 price target.</p>\r\n\r\n<p>Duck Creek Technologies shares fell 0.5% to $14.78 in pre-market trading.</p>\r\n\r\n<p><a href="https://www.benzinga.com/news/22/07/27928092/us-manufacturing-data-and-other-macro-issues-for-friday"><em>Check out this: US Manufacturing Data And Other Macro Issues For Friday </em></a></p>\r\n\r\n<p>&nbsp;</p>\r\n\r\n<p><strong>Breaking News </strong></p>\r\n\r\n<ul>\r\n\t<li><strong>Micron Technology Inc</strong> (NASDAQ:<a class="ticker" href="https://www.benzinga.com/stock/MU#NASDAQ">MU</a>) reported upbeat financial results for its third quarter, but issued weak guidance for its fourth quarter.</li>\r\n\t<li><strong>Accolade, Inc. </strong> (NASDAQ: ...
#    'created_at': '2022-07-01T09:26:58Z',
#    'headline': 'U.S. Stock Futures Edge Lower Ahead Of Manufacturing Data',
#    'id': 27928472,
#    'images': [{'size': 'large',
#      'url': 'https://cdn.benzinga.com/files/imagecache/2048x1536xUP/images/story/2022/07/01/image20.jpg'},
#     {'size': 'small',
#      'url': 'https://cdn.benzinga.com/files/imagecache/1024x768xUP/images/story/2022/07/01/image20.jpg'},
#     {'size': 'thumb',
#      'url': 'https://cdn.benzinga.com/files/imagecache/250x187xUP/images/story/2022/07/01/image20.jpg'}],
#    'source': 'benzinga',
#    'summary': 'Pre-open movers\n\nU.S. stock futures traded slightly lower in early pre-market trade on Friday after the Wall Street recorded its worst first half in over 50 years.',
#    'symbols': ['AAPL', 'ACCD', 'DCT', 'HI', 'MU'],
#    'updated_at': '2022-07-01T09:26:58Z',
#    'url': 'https://www.benzinga.com/news/earnings/22/07/27928472/u-s-stock-futures-edge-lower-ahead-of-manufacturing-data'},
#   {'author': 'Charles Gross',
#    'content': '',
#    'created_at': '2022-07-01T09:19:29Z',
#    'headline': 'Top Wall Street Bets Mentions for the Month of June: GME, TSLA, AMC, AMZN, AMD, AAPL, UVXY, NVDA, META, HOOD',
#    'id': 27928451,
#    'images': [],
#    'source': 'benzinga',
#    'summary': '',
#    'symbols': ['AAPL',
#     'AMC',
#     'AMD',
#     'AMZN',
#     'GME',
#     'HOOD',
#     'META',
#     'NVDA',
#     'TSLA',
#     'UVXY'],
#    'updated_at': '2022-07-01T09:19:29Z',
#    'url': 'https://www.benzinga.com/news/22/07/27928451/top-wall-street-bets-mentions-for-the-month-of-june-gme-tsla-amc-amzn-amd-aapl-uvxy-nvda-meta-hood'},
#   {'author': 'Charles Gross',
#    'content': '',
#    'created_at': '2022-07-01T09:01:47Z',
#    'headline': 'Bloomberg Reported Thursday Apple Raised iPhone and iPad Prices in Japan After Yen Selloff',
#    'id': 27928361,
#    'images': [],
#    'source': 'benzinga',
#    'summary': '',
#    'symbols': ['AAPL'],
#    'updated_at': '2022-07-01T09:01:47Z',
#    'url': 'https://www.benzinga.com/news/22/07/27928361/bloomberg-reported-thursday-apple-raised-iphone-and-ipad-prices-in-japan-after-yen-selloff'},
#   {'author': 'Benzinga Overnight Desk',
#    'content': '<p><strong>Apple Inc. </strong>(NASDAQ:<a class="ticker" href="https://www.benzinga.com/stock/AAPL#NASDAQ">AAPL</a>) has hiked <strong>iPhone</strong> and <strong>iPad</strong> prices in Japan, according to&nbsp;its regional website.</p>\r\n\r\n<p>The base model of the iPhone now costs JPY 117,800, compared to JPY 99,800 earlier, indicating a hike of about 18%.&nbsp;The iPhone 13 mini now comes at JPY 99,800.</p>\r\n\r\n<p><em>See Also:&nbsp;<a href="https://www.benzinga.com/money/how-to-buy-apple-stock/">How To Buy Apple (AAPL) Shares</a></em></p>\r\n\r\n<p>The iPad and iPad Air prices have risen by JPY 10,000 each. A 64-GB iPad Air with WiFi option now costs JPY 84,800. Nikkei Asia first reported the news.</p>\r\n\r\n<p>The hikes come as Japan&#39;s currency, the yen, continues to weaken.&nbsp;</p>\r\n\r\n<p>The&nbsp;U.S.&nbsp;dollar has surged about 17.7% against JPY in one year, with one yen worth $0.0074 at the time of writing&nbsp;compared with&nbsp;$0.0090&nbsp;a year earlier.</p>\r\n\r\n<p><strong>Price Action:&nbsp;</strong>Apple stock closed 1.8% lower at $136.72 in the regular session on Thursday, according to data from<a href="https://benzinga.grsm.io/register174"> Benzinga Pro.</a></p>\r\n\r\n<p><em>Read Next:&nbsp;<a href="https://www.benzinga.com/news/22/07/27926585/apples-former-top-corporate-lawyer-pleades-guilty-to-securities-fraud-insider-trading" rel="noopener noreferrer" target="_blank">Apple&#39;s Former Top Corporate Lawyer Pleads Guilty To Securities Fraud, Insider Trading</a></em></p>\r\n',
#    'created_at': '2022-07-01T05:00:15Z',
#    'headline': 'Apple Hikes iPhone, iPad Prices In Japan As Yen Weakens',
#    'id': 27927573,
#    'images': [{'size': 'large',
#      'url': 'https://cdn.benzinga.com/files/imagecache/2048x1536xUP/images/story/2022/07/01/youssef-sarhan-tze1kkj7lgg-unsplash.jpg'},
#     {'size': 'small',
#      'url': 'https://cdn.benzinga.com/files/imagecache/1024x768xUP/images/story/2022/07/01/youssef-sarhan-tze1kkj7lgg-unsplash.jpg'},
#     {'size': 'thumb',
#      'url': 'https://cdn.benzinga.com/files/imagecache/250x187xUP/images/story/2022
><a href="https://www.benzinga.com/news/22/06/27911536/heres-how-much-youd-have-now-if-you-invested-100-when-apple-sold-its-first-ever-iphone" target="_blank"><em>iPhone Turns 15: How Much Return $100 Investment In Apple Stock At Launch Would Have Fetched For You</em></a></p>\r\n\r\n<p><em>Photo via&nbsp;<a href="https://www.shutterstock.com/g/VideoFlow">VideoFlow</a>&nbsp;on Shutterstock</em></p>\r\n\r\n<p>&nbsp;</p>\r\n',
#    'created_at': '2022-07-01T04:25:20Z',
#    'headline': "Apple's Former Top Corporate Lawyer Pleads Guilty To Securities Fraud, Insider Trading",
#    'id': 27926585,
#    'images': [{'size': 'large',
#      'url': 'https://cdn.benzinga.com/files/imagecache/2048x1536xUP/images/story/2022/07/01/shutterstock_1815391877.jpg'},
#     {'size': 'small',
#      'url': 'https://cdn.benzinga.com/files/imagecache/1024x768xUP/images/story/2022/07/01/shutterstock_1815391877.jpg'},
#     {'size': 'thumb',
#      'url': 'https://cdn.benzinga.com/files/imagecache/250x187xUP/images/story/2022/07/01/shutterstock_1815391877.jpg'}],
#    'source': 'benzinga',
#    'summary': 'Apple Inc’s\xa0(NASDAQ:\xa0AAPL) former corporate secretary and director of corporate law,\xa0Gene Levoff, has admitted to being part of an insider trading scheme that ran for five years.',
#    'symbols': ['AAPL'],
#    'updated_at': '2022-07-01T04:27:53Z',
#    'url': 'https://www.benzinga.com/news/22/07/27926585/apples-former-top-corporate-lawyer-pleades-guilty-to-securities-fraud-insider-trading'},
#   {'author': 'Charles Gross',
#    'content': '',
#    'created_at': '2022-07-01T00:07:40Z',
#    'headline': 'Ten Stocks Trending on Discord for Thursday June 30, 2022: TSLA, UBS, ANPC, RIBT, KERN, NVDA, DRMA, SGH, AAPL, BBBY',
#    'id': 27926052,
#    'images': [],
#    'source': 'benzinga',
#    'summary': '',
#    'symbols': ['AAPL',
#     'ANPC',
#     'BBBY',
#     'DRMA',
#     'KERN',
#     'NVDA',
#     'RIBT',
#     'SGH',
#     'TSLA',
#     'UBS'],
#    'updated_at': '2022-07-01T00:07:40Z',
#    'url': 'https://www.benzinga.com/news/22/06/27926052/ten-stocks-trending-on-discord-for-thursday-june-30-2022-tsla-ubs-anpc-ribt-kern-nvda-drma-sgh-aapl'},
#   {'author': 'Charles Gross',
#    'content': '',
#    'created_at': '2022-07-01T00:04:14Z',
#    'headline': 'Top Wall Street Bets Mentions for Thursday June 30, 2022 After-Hours: GME, AMD, TSLA, JPM, AAPL, AMC, MSFT, NVDA, BBBY, UVXY',
#    'id': 27926036,
#    'images': [],
#    'source': 'benzinga',
#    'summary': '',
#    'symbols': ['AAPL',
#     'AMC',
#     'AMD',
#     'BBBY',
#     'GME',
#     'JPM',
#     'MSFT',
#     'NVDA',
#     'TSLA',
#     'UVXY'],
#    'updated_at': '2022-07-01T00:04:14Z',
#    'url': 'https://www.benzinga.com/news/22/06/27926036/top-wall-street-bets-mentions-for-thursday-june-30-2022-after-hours-gme-amd-tsla-jpm-aapl-amc-msft-n'}],
#  'next_page_token': None}
